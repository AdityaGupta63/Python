# %%
import pandas as pd

# %%
DataSet = pd.read_csv('./Data/smartphone_cleaned_v5.csv')

# %%
DataSet.head(40)
# Out:
#    brand_name                                        model   price  rating  \
# 0     oneplus                                OnePlus 11 5G   54999    89.0
# 1     oneplus                    OnePlus Nord CE 2 Lite 5G   19989    81.0
# 2     samsung                        Samsung Galaxy A14 5G   16499    75.0
# 3    motorola                         Motorola Moto G62 5G   14999    81.0
# 4      realme                           Realme 10 Pro Plus   24999    82.0
# 5     samsung      Samsung Galaxy F23 5G (6GB RAM + 128GB)   16999    80.0
# 6       apple                              Apple iPhone 14   65999    81.0
# 7      xiaomi                Xiaomi Redmi Note 12 Pro Plus   29999    86.0
# 8     nothing                              Nothing Phone 1   26749    85.0
# 9     oneplus                           OnePlus Nord 2T 5G   28999    84.0
# 10     realme                                Realme 10 Pro   18999    82.0
# ...

# %%
DataSet['model'][DataSet['processor_brand']=='snapdragon'].head(40)
# Out:
# 0                                   OnePlus 11 5G
# 1                       OnePlus Nord CE 2 Lite 5G
# 3                            Motorola Moto G62 5G
# 5         Samsung Galaxy F23 5G (6GB RAM + 128GB)
# 8                                 Nothing Phone 1
# 10                                  Realme 10 Pro
# 13                   Vivo T1 5G (6GB RAM + 128GB)
# 14                    Samsung Galaxy S23 Ultra 5G
# 17                           OPPO Reno 9 Pro Plus
# 20                                    OnePlus 11R
# 22                                 Poco X4 Pro 5G
# 23                           Xiaomi Redmi Note 12
# 25                       Samsung Galaxy S20 FE 5G
# 26    OnePlus Nord CE 2 Lite 5G (8GB RAM + 128GB)
# 29                                 OnePlus 11 Pro
# 30                Realme 10 Pro (8GB RAM + 128GB)
# 31                                    Poco X5 Pro
# 36                                   Oppo Reno 8T
# 37                    Samsung Galaxy S22 Ultra 5G
# ...

# %%
DataSet['model'][DataSet['has_ir_blaster']==True].head(40)
# Out:
# 7                          Xiaomi Redmi Note 12 Pro Plus
# 12                           Xiaomi Redmi Note 12 Pro 5G
# 22                                        Poco X4 Pro 5G
# 23                                  Xiaomi Redmi Note 12
# 31                                           Poco X5 Pro
# 38                       Xiaomi Redmi Note 12 Pro Max 5G
# 41                      Xiaomi Redmi Note 11 Pro Plus 5G
# 46                                  Xiaomi Redmi Note 11
# 51                                         iQOO Neo 7 5G
# 57                                 Xiaomi Redmi Note 10S
# 60                           Xiaomi Redmi Note 13 Pro 5G
# 64                      Poco M4 Pro 5G (6GB RAM + 128GB)
# 67      Xiaomi Redmi Note 12 Pro Plus (12GB RAM + 256GB)
# 74             Xiaomi Redmi Note 10T 5G (6GB RAM +128GB)
# 88                Xiaomi Redmi Note 11 (6GB RAM + 128GB)
# 93                                  Vivo X90 Pro Plus 5G
# ...

# %%
DataSet['model'][DataSet['price']<20000].head(40)
# Out:
# 1                     OnePlus Nord CE 2 Lite 5G
# 2                         Samsung Galaxy A14 5G
# 3                          Motorola Moto G62 5G
# 5       Samsung Galaxy F23 5G (6GB RAM + 128GB)
# 10                                Realme 10 Pro
# 11                                     Oppo A78
# 13                 Vivo T1 5G (6GB RAM + 128GB)
# 16                                     Vivo Y16
# 19                                     Vivo Y22
# 22                               Poco X4 Pro 5G
# 23                         Xiaomi Redmi Note 12
# 30              Realme 10 Pro (8GB RAM + 128GB)
# 41             Xiaomi Redmi Note 11 Pro Plus 5G
# 42                   Motorola Edge 20 Fusion 5G
# 44                                     Vivo Y35
# 45                        Samsung Galaxy M33 5G
# 46                         Xiaomi Redmi Note 11
# 47                                   Realme C33
# 48                    Vivo Y16 (4GB RAM + 64GB)
# 50      Samsung Galaxy A14 5G (6GB RAM + 128GB)
# ...
